# %%
import pandas as pd
import numpy as np

# %%
path="2021_Substack_Survey_Clean.csv"
df = pd.read_csv(path)
df
# Out:
#        Unnamed: 0  ResponseId                   Country  ConvertedCompYearly  \
# 0               9          10                    Sweden              51552.0
# 1              11          12                     Spain              46482.0
# 2              12          13                   Germany              77290.0
# 3              16          17                    Turkey              17748.0
# 4              17          18                    Canada              46135.0
# ...           ...         ...                       ...                  ...
# 45337       83434       83435  United States of America             160500.0
# 45338       83435       83436                     Benin               3960.0
# 45339       83436       83437  United States of America              90000.0
# 45340       83437       83438                    Canada             816816.0
# 45341       83438       83439                    Brazil              21168.0
#
#       YearsCodePro YearsCode  \
# 0                4         7
# 1                5        12
# 2                6        15
# 3                2         6
# 4                6         9
# ...            ...       ...
# 45337            5         6
# 45338            2         4
# 45339            4        10
# 45340            3         5
# 45341            4        14
#
#                                                  EdLevel  \
# 0        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                  ...
# 45337       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 45338       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 45339  Secondary school (e.g. American high school, G...
# 45340       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 45341                 Professional degree (JD, MD, etc.)
#
#                                                  OrgSize              Age  \
# 0                                     10 to 19 employees  25-34 years old
# 1                                     10 to 19 employees  25-34 years old
# 2                               1,000 to 4,999 employees  25-34 years old
# 3                                   100 to 499 employees  25-34 years old
# 4                                   500 to 999 employees  25-34 years old
# ...                                                  ...              ...
# 45337                                 20 to 99 employees  25-34 years old
# 45338  Just me - I am a freelancer, sole proprietor, ...  18-24 years old
# 45339                           10,000 or more employees  25-34 years old
# 45340                                 20 to 99 employees  25-34 years old
# 45341                                       I don’t know  18-24 years old
#
#       Gender  ... ASP.NET  Gatsby  Drupal  Heroku  Microsoft Azure    AWS  \
# 0        Man  ...   False   False   False   False            False  False
# 1        Man  ...   False   False   False   False            False   True
# 2        Man  ...   False   False   False   False            False  False
# 3        Man  ...   False   False   False   False            False   True
# 4        Man  ...   False   False   False   False            False   True
# ...      ...  ...     ...     ...     ...     ...              ...    ...
# 45337    Man  ...   False   False   False   False            False   True
# 45338    Man  ...   False   False   False   False            False  False
# 45339    Man  ...   False   False   False   False            False   True
# 45340    Man  ...   False   False   False    True            False  False
# 45341    Man  ...   False   False   False   False             True  False
#
#        Google Cloud Platform  DigitalOcean  Oracle Cloud Infrastructure  \
# 0                      False         False                        False
# 1                      False         False                        False
# 2                      False         False                        False
# 3                       True         False                        False
# 4                      False         False                        False
# ...                      ...           ...                          ...
# 45337                  False         False                        False
# 45338                  False         False                        False
# 45339                   True         False                        False
# 45340                  False         False                        False
# 45341                  False         False                        False
#
#        IBM Cloud or Watson
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 45337                False
# 45338                False
# 45339                False
# 45340                False
# 45341                False
#
# [45342 rows x 88 columns]

# %%
df["Country"].unique()
# Out:
# array(['Sweden', 'Spain', 'Germany', 'Turkey', 'Canada', 'Singapore',
#        'France', 'Switzerland',
#        'United Kingdom of Great Britain and Northern Ireland',
#        'Russian Federation', 'Israel', 'Ukraine',
#        'United States of America', 'Brazil', 'Bulgaria', 'Greece',
#        'Italy', 'Netherlands', 'Poland', 'Hungary', 'Pakistan', 'Nigeria',
#        'Albania', 'Bangladesh', 'Viet Nam', 'Romania', 'Sri Lanka',
#        'India', 'Lithuania', 'Slovenia', 'Croatia', 'Georgia', 'Denmark',
#        'Ireland', 'Lebanon', 'Bahrain', 'Egypt', 'Colombia', 'Australia',
#        'Belgium', 'Chile', 'Indonesia', 'Iran, Islamic Republic of...',
#        'Portugal', 'Slovakia', 'Armenia', 'Finland', 'Hong Kong (S.A.R.)',
#        'Argentina', 'Costa Rica', 'Peru', 'Japan', 'United Arab Emirates',
#        'Bolivia', 'Austria', 'South Africa', 'Norway', 'Serbia', 'Malta',
#        'Malaysia', 'Czech Republic', 'Belarus', 'Madagascar', 'Kenya',
#        'Uruguay', 'The former Yugoslav Republic of Macedonia', 'Botswana',
#        'Algeria', 'China', 'Mexico', 'Cyprus',
#        'Venezuela, Bolivarian Republic of...', 'Jordan',
#        'Dominican Republic', 'Ecuador', 'Luxembourg', 'Uzbekistan',
#        'Syrian Arab Republic', 'Zambia', 'Taiwan', 'Tunisia',
#        'South Korea', 'Paraguay', 'Iceland', 'Morocco', 'Guatemala',
#        'Cameroon', 'Republic of Moldova', 'Nepal', 'Kazakhstan',
#        'Estonia', 'Panama', 'Ethiopia', 'Cuba', 'Latvia',
#        "Lao People's Democratic Republic", 'Yemen', 'Thailand',
#        'Democratic Republic of the Congo', 'Somalia', 'Philippines',
#        'Azerbaijan', 'Saudi Arabia', 'Honduras', 'Angola',
#        'Bosnia and Herzegovina', 'United Republic of Tanzania',
#        'El Salvador', 'Iraq', 'Kosovo', 'Andorra', 'New Zealand',
#        'Dominica', 'Nomadic', 'Nicaragua', 'Mozambique',
#        'Trinidad and Tobago', 'Barbados', 'Mauritius', 'Kuwait', 'Ghana',
#        'Congo, Republic of the...', 'Myanmar', 'Republic of Korea',
#        'Cambodia', 'Kyrgyzstan', 'Uganda', 'Swaziland',
#        'Saint Kitts and Nevis', 'Rwanda', 'Monaco', 'Afghanistan',
#        'Turkmenistan', 'Libyan Arab Jamahiriya', 'Sudan', 'Montenegro',
#        'Isle of Man', 'Qatar', 'Haiti', 'Belize', 'Benin', 'Bhutan',
#        'Palestine', 'Mongolia', 'Tajikistan', 'Cape Verde', 'Oman',
#        "Côte d'Ivoire", 'Zimbabwe', 'Jamaica', 'Guyana', 'Namibia',
#        'Togo', 'Lesotho', 'Guinea', 'Senegal', 'Liberia', 'Suriname',
#        'Niger', 'Maldives', 'Saint Lucia', 'Djibouti', 'Malawi',
#        'San Marino', 'Saint Vincent and the Grenadines', 'Gambia',
#        'Burkina Faso', 'Fiji', 'Mauritania', 'Burundi', 'North Korea'],
#       dtype=object)

# %%
df["Country"].value_counts()
# Out:
# United States of America                                9620
# India                                                   3528
# Germany                                                 3161
# United Kingdom of Great Britain and Northern Ireland    2879
# Canada                                                  1694
#                                                         ...
# Saint Lucia                                                1
# Liberia                                                    1
# Guinea                                                     1
# Monaco                                                     1
# North Korea                                                1
# Name: Country, Length: 171, dtype: int64

# %%
list = ["Canada","United States of America"]
df2 = df[df["Country"].isin(list)]

# %%
q1 = np.quantile(df["ConvertedCompYearly"], .25)
q3 = np.quantile(df["ConvertedCompYearly"], .75)
IQR = q3-q1
cut_high = (1.5*IQR)+q3
cut_low = q1-(1.5*IQR)
print(f" Q1: {q1},Q3: {q3}, IQR: {IQR}, outlier high: {cut_high}, outlier low: {cut_low}")
# Out:
#  Q1: 27432.0,Q3: 100000.0, IQR: 72568.0, outlier high: 208852.0, outlier low: -81420.0

# %%
def new_column(row):
    if row["ConvertedCompYearly"] <= q1:
        return "low"
    elif row["ConvertedCompYearly"] >= cut_high:
        return "high"
    else:
        return "keep"
    
df["outlier"] = df.apply(new_column, axis=1)
df["outlier"].value_counts()
# Out:
# keep    31265
# low     11340
# high     2737
# Name: outlier, dtype: int64
